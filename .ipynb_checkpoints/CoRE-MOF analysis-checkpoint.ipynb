# %%
import pandas as pd
import glob
from tqdm.notebook import tqdm, trange
from typing import List, Tuple

# %%
df = pd.read_csv('coremof-mofid.txt', sep=';')
df
# Out:
#                                                    mofid  \
# 0               [Co].[O-]C(=O)c1ccncc1 MOFid-v1.rtl.cat0
# 1               [Co].[O-]C(=O)c1ccncc1 MOFid-v1.rtl.cat0
# 2      Cl[Mn][Mn]Cl.[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=...
# 3      Cl[Co][Co]Cl.[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=...
# 4      [O]S(c1ccc(cc1)C1=C2C=CC(=C(c3ccc(cc3)S([O])([...
# ...                                                  ...
# 14021  [O]P(=O)(c1ccccc1)c1ccccc1.[Zn][OH][Zn] MOFid-...
# 14022  CC1=NC(=N[N]1)CC1=N[N]C(=N1)C.CC1=NN=C([N]1)CC...
# 14023  [O-]C(=O)c1ccc(cc1)[Si](c1ccc(cc1)C(=O)[O-])(c...
# 14024   [Fe].[Na].[O-]C(=O)C(=O)[O-] MOFid-v1.ERROR.cat5
# 14025  [Cu][Cu].[O-]C(=O)c1ccc(cc1)c1cc(cc(c1)c1ccc(c...
#
#                                          mof_name
# 0                                    ABAVIJ_clean
# 1                                    ABAVOP_clean
# 2                                    ABAYIO_clean
# 3                                    ABAYOU_clean
# ...

# %%
def process_mofid(s: str) -> Tuple[List[str], List[str]]
